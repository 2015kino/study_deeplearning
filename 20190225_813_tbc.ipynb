# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork026.jpg')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork027.jpg')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork020.png')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()
