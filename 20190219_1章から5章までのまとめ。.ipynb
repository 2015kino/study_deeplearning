# %%
#Re:No6

#此処までのおさらい。1章ではPythonを使って行うけれど、こんな感じのを使うよって進む。
#最も活躍しているのはNumpy。配列計算。

#2章ではパーセプトロンというアルゴを習う。
#これは入出力を纏めた考え、で重み、バイアスというパラメータを設定している。

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

img = imread("D:\python\deeplearning\pycontent\dataset\ec691597s.png")
plt.figure(figsize=(10, 50))
plt.imshow(img)
plt.show()

# %%
#最も長く説明していたのはXORの話。

#ニューラルネットワークの話はこれがもっと大きくなる。
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline
img = imread("D:\python\deeplearning\pycontent\dataset\Activationfunction10.png")
plt.figure(figsize=(10, 50))
plt.imshow(img)

plt.show()

# %%
#１がバイアスでxが重み。それを計算してhoで計算結果をそれぞれの関数で変換して値を出力。
#それを何回も繰り返して、画像の特徴点を平均化していきそれは此れというのを見つけていく。

#平均。なのでもちろんデータが必要。そこで扱われるのがビッグデータで今回はmnistセットというものにお世話になっている
#いろんな人の書いた数字がこの中に入っていて、それは何？っていうのを表示させる。
#・訓練画像=60000枚
#・テスト画像=10000枚
#0-9の数字が28ｘ28の画像データとして入っている。

#で、この訓練されたデータと、テストデータを使って最適なパラメータ探索を行っていくというのが機械学習のセオリー。
#SIFT,SURF,HOGは特徴量。どの点を学習点としてスクリーニングしていくかという話

# %matplotlib inline
img = imread('D:/python/deeplearning/pycontent/dataset/nyuralnetwork030.png')
plt.figure(figsize=(10, 50))
plt.imshow(img)

plt.show()

# %%
#此処でさらっと出てくるのが損失関数。
#データに問題はない？という関数だ。
#これは少し前に出ていたけれど、写真はサルを示しているのに機械学習の答えはマントヒヒをさす、みたいな感じの。
#機械学習は特徴量を算出して平均化して、それを答えとして提示する。
#その提示した答えももちろん人なので、特徴量のみを操作したデータを用意すれば別人が出来上がる。
#なんてったって数字だからだ。。。とまとめてないなｗ。

#機械学習は最初のパラメータが適切かどうか？ってところによるので、そのパラメータを検出しないといけない。
#それを勾配法という手段を使って求める。

# %%
#流れとしてはこんな感じになる
#「バッチ用意（大量データ）⇔勾配の算出⇔パラメータ更新」　→　完了
#上記鍵括弧間を繰り返すのが流れ。

#長時間かかんじゃん！！ってなるわけである。
#そこで人の編み出した手法が使われる。これが誤差逆伝播法。

img = imread('D:/python/deeplearning/pycontent/dataset/ErrorBackPropagationMethod001.png')
plt.figure(figsize=(10, 4)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
#りんご、みかんとかあって、最終的に消費税払ったけれど、実際のりんごの値段はどれだけってのを逆から計算していく方法。
#此処でわかるのが各ノードの計算点。
#つまり最初と最後の計算方法がわかれば後は往復しても、その計算結果に則ってすれば途中計算省けるじゃん的発想

img = imread('D:/python/deeplearning/pycontent/dataset/ErrorBackPropagationMethod033.png')
plt.figure(figsize=(50, 10)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
#それが上記のようになる。
#手書き文字の大量データ⇔勾配の算出（Affine,ReLU)⇔パラメータ更新⇔結果（Softmax）
#っというのが、ざっとしてるけれど此処までの流れ。

# %%
#5章までは機械学習がどうやって画像を認識するのか？をテーマにしている。
#6章からはそれをどうやって効率よくかつ早くできるか？をテーマにしている。そのため、自分でも勉強しろよって言い方が多くなってくる。
