# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork018.png')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork019.png')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork022.jpg')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork023.jpg')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork024.jpg')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()

# %%
img = imread('D:/python/deeplearning/pycontent/dataset/ConvolutionNeuralNetwork025.jpg')
plt.figure(figsize=(50, 8)) # figureの縦横の大きさ
plt.imshow(img)

plt.show()
